# %% [markdown]
# # Parse Rules
# Inspect bundled market rule templates and convert them into `MarketSpec` objects.

# %%
from pmtmax.examples import example_market_specs
example_market_specs(["Seoul", "NYC"])
