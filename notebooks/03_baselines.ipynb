# %% [markdown]
# # Baselines
# Train and inspect baseline probabilistic models.

# %%
# !uv run pmtmax train-baseline --model-name gaussian_emos
