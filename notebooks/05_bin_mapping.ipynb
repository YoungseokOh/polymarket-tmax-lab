# %% [markdown]
# # Bin Mapping
# Inspect how probabilistic daily-max forecasts map to Polymarket outcomes.

# %%
from pmtmax.examples import example_market_specs
from pmtmax.modeling.bin_mapper import map_normal_to_outcomes
spec = example_market_specs(["Seoul"])[0]
map_normal_to_outcomes(spec, mean=8.0, std=1.0)
